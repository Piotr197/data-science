# %%
import numpy as np

# %%
import pandas as pd

# %%
auta = pd.read_csv('samochody1tys.csv')

# %%
 #wyświetlanie pierwszych rekordów pliku, domyślnie jest 5 wierszy.
auta.head()
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
 #wyświetlanie 3 ostatnich rekordów pliku, domyślnie jest 5 wierszy
auta.tail(3)
# Out:
#       id    marka    model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 997  997  Renault    Modus         2004.0        Benzyna             1200.0
# 998  998     Audi    A3 8L         2000.0        Benzyna             1595.0
# 999  999    Volvo  XC 60 I         2016.0         Diesel             1969.0
#
#      przebieg      cena  wojewodztwo
# 997  168111.0   10900.0      Łódzkie
# 998  226500.0    5400.0  Małopolskie
# 999   13617.0  136900.0  Małopolskie

# %%
#wyświetlanie indeksów
auta.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#wyświetlanie nazw kolumn
auta.columns
# Out:
# Index(['id', 'marka', 'model', 'rok_produkcji', 'rodzaj_silnika',
#        'pojemnosc_silnika', 'przebieg', 'cena', 'wojewodztwo'],
#       dtype='object')

# %%
#zamiana na tablicę NumPy
auta.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
#wyświetlenie krótkiego podsumowania danych
auta.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
#transpozycja danych
auta.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
#sortowanie alfabetycznie malejąco według nazw kolumn
auta.sort_index(axis=1, ascending=False)
# Out:
#         wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0      Dolnośląskie         2014.0         Diesel  160000.0
# 1    Świętokrzyskie         2012.0         Diesel  149000.0
# 2          Opolskie         2004.0    Benzyna+CNG   99000.0
# 3           Łódzkie         2008.0        Benzyna   93000.0
# 4     Wielkopolskie         2010.0         Diesel  127428.0
# ..              ...            ...            ...       ...
# 995     Małopolskie         2009.0         Diesel  182000.0
# 996       Lubelskie         2012.0        Benzyna   42700.0
# 997         Łódzkie         2004.0        Benzyna  168111.0
# 998     Małopolskie         2000.0        Benzyna  226500.0
# 999     Małopolskie         2016.0         Diesel   13617.0
#
#      pojemnosc_silnika        model       marka   id      cena
# 0               1600.0  X-Trail III      Nissan    0   75900.0
# 1               2000.0       X1 E84         BMW    1   70900.0
# ...

# %%
#sortowanie według rodzaju silnika, alfabetycznie rosnąco
auta.sort_values(by="rodzaj_silnika")
# Out:
#       id          marka           model  rok_produkcji rodzaj_silnika  \
# 825  825           Ford       Focus Mk3         2016.0        Benzyna
# 362  362          Dacia       Sandero I         2009.0        Benzyna
# 579  579  Mercedes-Benz        CLK W208         2000.0        Benzyna
# 360  360           Opel           Mokka         2017.0        Benzyna
# 359  359          Mazda           6 III         2017.0        Benzyna
# ..   ...            ...             ...            ...            ...
# 680  680         Toyota        Auris II         2016.0        Hybryda
# 687  687         Toyota       Yaris III         2016.0        Hybryda
# 689  689         Toyota       Prius III         2010.0        Hybryda
# 719  719         Toyota         RAV4 IV         2016.0        Hybryda
# 410  410            BMW  Seria 7 G11/12         2017.0        Hybryda
#
#      pojemnosc_silnika  przebieg      cena         wojewodztwo
# 825             1596.0    8140.0   51900.0       Wielkopolskie
# ...

# %%
#wybranie pojedynczej kolumny
auta['marka']
# Out:
# 0          Nissan
# 1             BMW
# 2            Opel
# 3         Hyundai
# 4      Volkswagen
#           ...
# 995    Alfa Romeo
# 996         Škoda
# 997       Renault
# 998          Audi
# 999         Volvo
# Name: marka, Length: 1000, dtype: object

# %%
#wybranie dwóch pojedynczych kolumn i połączenie ich
auta['marka'] + ' ' + auta['model']
# Out:
# 0      Nissan X-Trail III
# 1              BMW X1 E84
# 2           Opel Zafira A
# 3           Hyundai i10 I
# 4           Volkswagen CC
#               ...
# 995        Alfa Romeo 159
# 996        Škoda Fabia II
# 997         Renault Modus
# 998            Audi A3 8L
# 999         Volvo XC 60 I
# Length: 1000, dtype: object

# %%
#wybieranie kliku rekorów, w tym przypadku 5 pierwszych
auta[0:5]
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
#wybieranie na podst. id
auta.loc[3]
# Out:
# id                         3
# marka                Hyundai
# model                  i10 I
# rok_produkcji           2008
# rodzaj_silnika       Benzyna
# pojemnosc_silnika       1100
# przebieg               93000
# cena                   11900
# wojewodztwo          Łódzkie
# Name: 3, dtype: object

# %%
#wybieranie rekordów od 0 do 15, z wybranymi kolumn
auta.loc[0:15,['model', 'przebieg', 'cena']]
# Out:
#             model  przebieg     cena
# 0     X-Trail III  160000.0  75900.0
# 1          X1 E84  149000.0  70900.0
# 2        Zafira A   99000.0   9800.0
# 3           i10 I   93000.0  11900.0
# 4              CC  127428.0  49900.0
# 5             500   36800.0  74200.0
# 6       X-Trail I  174000.0  23200.0
# 7       Toledo II  140700.0   8150.0
# 8              CC   52000.0  97000.0
# 9            Juke   18000.0  56900.0
# 10  Corolla Seria   26415.0  53000.0
# 11    Seria 5 E39  254900.0  17500.0
# 12       Jetta A6   59000.0  59900.0
# 13             A1   90000.0  39999.0
# 14    Seria 3 E90  246000.0  27999.0
# 15   C4 Picasso I  181658.0  16900.0

# %%
#wybieranie jednego wyznaczonego rekordu, z wybranymi kolumnami
auta.loc[236,['model', 'przebieg', 'cena']]
# Out:
# model       Astra H
# przebieg     154000
# cena          19500
# Name: 236, dtype: object

# %%
#wybieranie tylko jednej wartości z wybranego rekordu
auta.loc[15, 'model']
# Out:
# 'C4 Picasso I'

# %%
#inna metoda, działanie jak wyżej
auta.at[15, 'model']
# Out:
# 'C4 Picasso I'

# %%
#wybieranie na podst. id
auta.iloc[5]
# Out:
# id                             5
# marka                       Fiat
# model                        500
# rok_produkcji               2014
# rodzaj_silnika       Elektryczny
# pojemnosc_silnika              1
# przebieg                   36800
# cena                       74200
# wojewodztwo              Śląskie
# Name: 5, dtype: object

# %%
#wybieranie rekordów ze wskazanego przedziału i wyświetlenie kolumn ze wskazanego przedziału  
auta.iloc[7:12, 4:9]
# Out:
#    rodzaj_silnika  pojemnosc_silnika  przebieg     cena  wojewodztwo
# 7         Benzyna             1800.0  140700.0   8150.0    Pomorskie
# 8          Diesel             1968.0   52000.0  97000.0    Pomorskie
# 9         Benzyna             1197.0   18000.0  56900.0  Mazowieckie
# 10        Benzyna             1329.0   26415.0  53000.0     Lubuskie
# 11         Diesel             3000.0  254900.0  17500.0  Mazowieckie

# %%
#wybieranie wskazanych rekordów, ze wszystkimi kolumnami
auta.loc[[1,2,4],:]
# Out:
#    id       marka     model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 1   1         BMW    X1 E84         2012.0         Diesel             2000.0
# 2   2        Opel  Zafira A         2004.0    Benzyna+CNG             1600.0
# 4   4  Volkswagen        CC         2010.0         Diesel             1968.0
#
#    przebieg     cena     wojewodztwo
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie
# 4  127428.0  49900.0   Wielkopolskie

# %%
#wybieranie rekordów ze wskazanego przedziału ze wszystkimi kolumnami
auta.iloc[56:60,:]
# Out:
#     id       marka       model  rok_produkcji rodzaj_silnika  \
# 56  56        Opel  Insignia A         2014.0         Diesel
# 57  57  Volkswagen     Polo IV         2008.0        Benzyna
# 58  58        Ford   Focus Mk3         2017.0        Benzyna
# 59  59     Peugeot       307 I         2003.0        Benzyna
#
#     pojemnosc_silnika  przebieg     cena    wojewodztwo
# 56             2000.0   80400.0  61900.0   Podkarpackie
# 57             1198.0  158452.0  11900.0        Śląskie
# 58             1598.0       7.0  77900.0       Lubuskie
# 59             1600.0  179765.0   8500.0  Wielkopolskie

# %%
#wybieranie wszystkich rekordów i wyświetlenie kolumn ze wskazanego przedziału
auta.iloc[:, 1:3]
# Out:
#           marka        model
# 0        Nissan  X-Trail III
# 1           BMW       X1 E84
# 2          Opel     Zafira A
# 3       Hyundai        i10 I
# 4    Volkswagen           CC
# ..          ...          ...
# 995  Alfa Romeo          159
# 996       Škoda     Fabia II
# 997     Renault        Modus
# 998        Audi        A3 8L
# 999       Volvo      XC 60 I
#
# [1000 rows x 2 columns]

# %%
#wybieranie wartości ze wskazanego rekordu i wskazanej kolumny
auta.iloc[124,8]
# Out:
# 'Wielkopolskie'

# %%
#inna metoda, działanie jak wyżej
auta.iat[124,8]
# Out:
# 'Wielkopolskie'

# %%
#wybieranie tylko tych rekordów których wartość w kolumnach spełniają wskazane wymaganie.
#w moim przypadku wybieranie tylko takich samochodów których cena jest mniejsza niż 20000
auta[auta.cena < 20000.]
# Out:
#       id    marka         model  rok_produkcji rodzaj_silnika  \
# 2      2     Opel      Zafira A         2004.0    Benzyna+CNG
# 3      3  Hyundai         i10 I         2008.0        Benzyna
# 7      7     Seat     Toledo II         2000.0        Benzyna
# 11    11      BMW   Seria 5 E39         2002.0         Diesel
# 15    15  Citroën  C4 Picasso I         2007.0         Diesel
# ..   ...      ...           ...            ...            ...
# 987  987   Toyota         Camry         1992.0        Benzyna
# 989  989      BMW   Seria 5 E39         2002.0         Diesel
# 994  994     Fiat      Bravo II         2007.0         Diesel
# 997  997  Renault         Modus         2004.0        Benzyna
# 998  998     Audi         A3 8L         2000.0        Benzyna
#
#      pojemnosc_silnika  przebieg     cena         wojewodztwo
# 2               1600.0   99000.0   9800.0            Opolskie
# 3               1100.0   93000.0  11900.0             Łódzkie
# ...

# %%
#użycie metody isin() do filtrowania danych
#w moim przypadku pzefiltrowanie tylko tych danych które w kolumnie rodzaj_silnika mają wartość Benzyna lub Benzyna+CNG
auta[auta['rodzaj_silnika'].isin(['Benzyna', 'Benzyna+CNG'])]
# Out:
#       id    marka          model  rok_produkcji rodzaj_silnika  \
# 2      2     Opel       Zafira A         2004.0    Benzyna+CNG
# 3      3  Hyundai          i10 I         2008.0        Benzyna
# 7      7     Seat      Toledo II         2000.0        Benzyna
# 9      9   Nissan           Juke         2016.0        Benzyna
# 10    10   Toyota  Corolla Seria         2015.0        Benzyna
# ..   ...      ...            ...            ...            ...
# 992  992  Renault        Clio IV         2017.0        Benzyna
# 993  993     Fiat        Tipo II         2017.0        Benzyna
# 996  996    Škoda       Fabia II         2012.0        Benzyna
# 997  997  Renault          Modus         2004.0        Benzyna
# 998  998     Audi          A3 8L         2000.0        Benzyna
#
#      pojemnosc_silnika  przebieg     cena  wojewodztwo
# 2               1600.0   99000.0   9800.0     Opolskie
# 3               1100.0   93000.0  11900.0      Łódzkie
# ...

# %%
#wybór średniej arytmentycznej cen wszystkich samochodów
auta['cena'].mean()
# Out:
# 51942.181

# %%
#zapis w auta_ceny 15 cen pierwszych 15 samochodów
auta_ceny = auta.loc[0:15,['cena']]

# %%
#wybór auta_ceny
auta_ceny
# Out:
#        cena
# 0   75900.0
# 1   70900.0
# 2    9800.0
# 3   11900.0
# 4   49900.0
# 5   74200.0
# 6   23200.0
# 7    8150.0
# 8   97000.0
# 9   56900.0
# 10  53000.0
# 11  17500.0
# 12  59900.0
# 13  39999.0
# 14  27999.0
# 15  16900.0

# %%
#zastosowanie metody numpy.cumsum, która dodaje kolejne wartości w kolumnie
auta_ceny.apply(np.cumsum)
# Out:
#         cena
# 0    75900.0
# 1   146800.0
# 2   156600.0
# 3   168500.0
# 4   218400.0
# 5   292600.0
# 6   315800.0
# 7   323950.0
# 8   420950.0
# 9   477850.0
# 10  530850.0
# 11  548350.0
# 12  608250.0
# 13  648249.0
# 14  676248.0
# 15  693148.0

# %%
#zastosowanie wyrażenia lambda do obliczenia róznicy pomiędzy maksymalną a minimalną ceną
auta_ceny.apply(lambda x : x.max() - x.min() )
# Out:
# cena    88850.0
# dtype: float64

# %%
#zapisanie w auta_rok, lat produkcji wszystkich samochodów
auta_rok = auta.iloc[0:999,[3]]

# %%
#wybieranie auta_rok
auta_rok
# Out:
#      rok_produkcji
# 0           2014.0
# 1           2012.0
# 2           2004.0
# 3           2008.0
# 4           2010.0
# ..             ...
# 994         2007.0
# 995         2009.0
# 996         2012.0
# 997         2004.0
# 998         2000.0
#
# [999 rows x 1 columns]

# %%
s = auta_rok.squeeze()

# %%
s.to_numpy()
# Out:
# array([2014., 2012., 2004., 2008., 2010., 2014., 2004., 2000., 2014.,
#        2016., 2015., 2002., 2014., 2011., 2008., 2007., 2003., 2017.,
#        2017., 2012., 2017., 2017., 2006., 2011., 2008., 2001., 2003.,
#        2001., 2009., 2010., 2011., 2002., 2017., 2017., 2002., 2008.,
#        2017., 2016., 2006., 2010., 2004., 2004., 2017., 2017., 2007.,
#        2016., 1997., 2012., 2007., 2007., 2003., 2006., 2016., 2016.,
#        2008., 2014., 2014., 2008., 2017., 2003., 2016., 2003., 2008.,
#        2008., 2007., 2009., 2013., 2009., 1994., 2000., 2016., 2017.,
#        2016., 2009., 2007., 2007., 2016., 2009., 2017., 2017., 2002.,
#        2012., 2000., 2005., 2007., 2005., 2007., 2012., 2003., 2009.,
#        2008., 2005., 2017., 2001., 2005., 2009., 2017., 2012., 2016.,
#        2007., 2003., 2009., 2014., 2007., 2009., 2002., 2005., 2001.,
#        2009., 2017., 2005., 2007., 2009., 2017., 2009., 2006., 2016.,
# ...

# %%
s.value_counts()
# Out:
# 2017.0    132
# 2007.0     81
# 2016.0     76
# 2006.0     76
# 2009.0     63
# 2008.0     59
# 2005.0     56
# 2014.0     51
# 2004.0     48
# 2010.0     48
# 2003.0     42
# 2012.0     39
# 2011.0     39
# 2002.0     36
# 2015.0     32
# 2013.0     32
# 2001.0     29
# 2000.0     19
# 1999.0     10
# 1998.0      7
# 1997.0      5
# 1994.0      4
# 1995.0      3
# 1992.0      3
# 1984.0      2
# 1986.0      2
# 1979.0      1
# 1993.0      1
# 1991.0      1
# 1988.0      1
# 1996.0      1
# Name: rok_produkcji, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
paliwo = auta.iloc[0:999,[4]]

# %%
paliwo1 = paliwo.squeeze()

# %%
paliwo1.to_numpy()
# Out:
# array(['Diesel', 'Diesel', 'Benzyna+CNG', 'Benzyna', 'Diesel',
#        'Elektryczny', 'Diesel', 'Benzyna', 'Diesel', 'Benzyna', 'Benzyna',
#        'Diesel', 'Benzyna', 'Benzyna', 'Diesel', 'Diesel', 'Diesel',
#        'Diesel', 'Diesel', 'Diesel', 'Benzyna', 'Diesel', 'Diesel',
#        'Diesel', 'Diesel', 'Benzyna+LPG', 'Diesel', 'Benzyna+LPG',
#        'Diesel', 'Diesel', 'Diesel', 'Benzyna', 'Benzyna', 'Benzyna',
#        'Benzyna', 'Diesel', 'Diesel', 'Benzyna', 'Benzyna', 'Diesel',
#        'Diesel', 'Benzyna', 'Benzyna', 'Diesel', 'Benzyna', 'Diesel',
#        'Benzyna', 'Diesel', 'Diesel', 'Benzyna', 'Diesel', 'Diesel',
#        'Diesel', 'Diesel', 'Benzyna', 'Diesel', 'Diesel', 'Benzyna',
#        'Benzyna', 'Benzyna', 'Diesel', 'Benzyna+LPG', 'Benzyna',
#        'Benzyna', 'Diesel', 'Diesel', 'Diesel', 'Diesel', 'Benzyna+LPG',
#        'Benzyna', 'Benzyna', 'Diesel', 'Diesel', 'Diesel', 'Diesel',
#        'Diesel', 'Diesel', 'Benzyna', 'Benzyna', 'Diesel', 'Benzyna',
# ...

# %%
type(paliwo1)
# Out:
# pandas.core.series.Series

# %%
paliwo1.str.lower()
# Out:
# 0           diesel
# 1           diesel
# 2      benzyna+cng
# 3          benzyna
# 4           diesel
#           ...
# 994         diesel
# 995         diesel
# 996        benzyna
# 997        benzyna
# 998        benzyna
# Name: rodzaj_silnika, Length: 999, dtype: object

# %%
paliwo1.str.upper()
# Out:
# 0           DIESEL
# 1           DIESEL
# 2      BENZYNA+CNG
# 3          BENZYNA
# 4           DIESEL
#           ...
# 994         DIESEL
# 995         DIESEL
# 996        BENZYNA
# 997        BENZYNA
# 998        BENZYNA
# Name: rodzaj_silnika, Length: 999, dtype: object

# %%
pieces = [auta[:100], auta[100:500], auta[500:800], auta[800:1000]]

# %%
pd.concat(pieces)
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
left = auta[:10]

# %%
right =  auta[40:50]

# %%
samochod = auta.iloc[5]

# %%
auta1 = auta.copy()

# %%
auta1.append(samochod, ignore_index=True)
# Out:
#        id       marka        model  rok_produkcji rodzaj_silnika  \
# 0       0      Nissan  X-Trail III         2014.0         Diesel
# 1       1         BMW       X1 E84         2012.0         Diesel
# 2       2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3       3     Hyundai        i10 I         2008.0        Benzyna
# 4       4  Volkswagen           CC         2010.0         Diesel
# ...   ...         ...          ...            ...            ...
# 996   996       Škoda     Fabia II         2012.0        Benzyna
# 997   997     Renault        Modus         2004.0        Benzyna
# 998   998        Audi        A3 8L         2000.0        Benzyna
# 999   999       Volvo      XC 60 I         2016.0         Diesel
# 1000    5        Fiat          500         2014.0    Elektryczny
#
#       pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0                1600.0  160000.0   75900.0    Dolnośląskie
# 1                2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
stacked = auta1.stack()

# %%
stacked
# Out:
# 0    id                             0
#      marka                     Nissan
#      model                X-Trail III
#      rok_produkcji               2014
#      rodzaj_silnika            Diesel
#                              ...
# 999  rodzaj_silnika            Diesel
#      pojemnosc_silnika           1969
#      przebieg                   13617
#      cena                      136900
#      wojewodztwo          Małopolskie
# Length: 9000, dtype: object

# %%
stacked.unstack()
# Out:
#       id       marka        model rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III          2014         Diesel
# 1      1         BMW       X1 E84          2012         Diesel
# 2      2        Opel     Zafira A          2004    Benzyna+CNG
# 3      3     Hyundai        i10 I          2008        Benzyna
# 4      4  Volkswagen           CC          2010         Diesel
# ..   ...         ...          ...           ...            ...
# 995  995  Alfa Romeo          159          2009         Diesel
# 996  996       Škoda     Fabia II          2012        Benzyna
# 997  997     Renault        Modus          2004        Benzyna
# 998  998        Audi        A3 8L          2000        Benzyna
# 999  999       Volvo      XC 60 I          2016         Diesel
#
#     pojemnosc_silnika przebieg    cena     wojewodztwo
# 0                1600   160000   75900    Dolnośląskie
# 1                2000   149000   70900  Świętokrzyskie
# ...

# %%
modele = auta.iloc[0:5,[2]]

# %%
modele
# Out:
#          model
# 0  X-Trail III
# 1       X1 E84
# 2     Zafira A
# 3        i10 I
# 4           CC

# %%
col = pd.DataFrame({'raw_grade' : ['a', 'b', 'b', 'a', 'e']})

# %%
modele = modele.join(col)

# %%
modele
# Out:
#          model raw_grade grade
# 0  X-Trail III         a     a
# 1       X1 E84         b     b
# 2     Zafira A         b     b
# 3        i10 I         a     a
# 4           CC         e     e

# %%
modele['grade'] = modele['raw_grade'].astype('category')

# %%
modele['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
modele['grade'].cat.categories = ['very good', 'good', 'very bad']

# %%
modele['grade'] = modele['grade'].cat.set_categories(['very bad', 'bad', 'medium', 'good', 'very good'])

# %%
modele['grade']
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
modele.sort_values(by='grade')
# Out:
#          model raw_grade      grade
# 4           CC         e   very bad
# 1       X1 E84         b       good
# 2     Zafira A         b       good
# 0  X-Trail III         a  very good
# 3        i10 I         a  very good

# %%
modele.groupby('grade').size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    2
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plot = auta.iloc[0:50, [6,7]]

# %%
plot
# Out:
#     przebieg     cena
# 0   160000.0  75900.0
# 1   149000.0  70900.0
# 2    99000.0   9800.0
# 3    93000.0  11900.0
# 4   127428.0  49900.0
# ..       ...      ...
# 95  195000.0  29900.0
# 96       5.0  46700.0
# 97  166000.0  19999.0
# 98       6.0  69990.0
# 99  211000.0  13300.0
#
# [100 rows x 2 columns]

# %%
#plot = plot.cumsum()

# %%
plot.plot()
